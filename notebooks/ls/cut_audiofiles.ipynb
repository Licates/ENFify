# %%
import numpy as np
import os
import sys
import random
from scipy.io import wavfile
import matplotlib.pyplot as plt

sys.path.insert(0, '/home/leo_dacasi/Dokumente/summerofcode/ENFify/enfify')
from preprocessing import downsampling, list_files_in_directory, cut_audio,

# %%
def ffmpeg_filenames_cut(input_dir, output_dir):
    try:
        # List all files in the directory
        files = os.listdir(input_dir)
        # Filter out directories, only keep files
        raw_files = [f for f in files if os.path.isfile(os.path.join(input_dir, f))]
        cut_files = []
        files = []

        for raw in raw_files:
            cut_file = output_dir + '/cut_'+raw
            cut_files.append(cut_file)
        
        for raw in raw_files:
            files.append(input_dir + '/' + raw)

        return files, cut_files

    except FileNotFoundError:
        return f"The directory {input_dir} does not exist."
    except PermissionError:
        return f"Permission denied to access {input_dir}."

def cut_audio(input_file, output_file, cut_begin, cut_end):
    os.system(f'. /home/$USER/miniforge3/etc/profile.d/conda.sh; conda activate enfify; ffmpeg -i {input_file} -filter_complex "[0]atrim=end={cut_begin},asetpts=PTS-STARTPTS[a1]; \
 [0]atrim=start={cut_end},asetpts=PTS-STARTPTS[a2]; \
 [a1][a2]concat=n=2:v=0:a=1[out]" -map "[out]" {output_file}')
    

def mult_cut_audio(input_file, output_file, cut_begin_1, cut_end_1, cut_begin_2, cut_end_2, cut_begin_3, cut_end_3):
    os.system(f'. /home/$USER/miniforge3/etc/profile.d/conda.sh; conda activate enfify; ffmpeg -i {input_file} -filter_complex "[0]atrim=end={cut_begin_1},asetpts=PTS-STARTPTS[a1]; \
 [0]atrim=start={cut_end_1}:end={cut_begin_2},asetpts=PTS-STARTPTS[a2]; \
 [0]atrim=start={cut_end_2}:end={cut_begin_3},asetpts=PTS-STARTPTS[a3]; \
 [0]atrim=start={cut_end_3},asetpts=PTS-STARTPTS[a4]; \
 [a1][a2][a3][a4]concat=n=4:v=0:a=1[out]" -map "[out]" {output_file}')

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data'
cut_begin = 60
cut_end = 120

files, cut_files = ffmpeg_filenames_cut(input_dir, output_dir)

for i in range(len(files)):

    cut_audio(files[i], cut_files[i], cut_begin, cut_end)
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_mulaw @ 0x5dfeb9de5dc0] Guessed Channel Layout: stereo
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data/1082.wav':
#   Duration: 00:14:58.62, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_mulaw ([7][0][0][0] / 0x0007), 8000 Hz, stereo, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data/cut_1082.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, stereo, s16, 256 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5dfeb9de5f80] video:0KiB audio:26207KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000291%
# size=   26207KiB time=00:13:58.62 bitrate= 256.0kbits/s speed=1.57e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60f4b08d61c0] Guessed Channel Layout: stereo
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data/down_1082.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:14:58.62, bitrate: 32 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, stereo, s16, 32 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data/cut_down_1082.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, stereo, s16, 32 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x60f4b08d6380] video:0KiB audio:3276KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002325%
# size=    3276KiB time=00:13:58.62 bitrate=  32.0kbits/s speed=2.33e+04x

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data'
cut_begin_1 = 60
cut_end_1 = 120
cut_begin_2 = 240
cut_end_2 = 300
cut_begin_3 = 420
cut_end_3 = 480

files, cut_files = ffmpeg_filenames_cut(input_dir, output_dir)

for i in range(len(files)):
    mult_cut_audio(files[i], cut_files[i], cut_begin_1, cut_end_1, cut_begin_2, cut_end_2, cut_begin_3, cut_end_3)
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_mulaw @ 0x5a1eed67d240] Guessed Channel Layout: stereo
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data/1082.wav':
#   Duration: 00:14:58.62, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_mulaw ([7][0][0][0] / 0x0007), 8000 Hz, stereo, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   Stream #0:0 (pcm_mulaw) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data/cut_1082.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, stereo, s16, 256 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a1eed65b780] video:0KiB audio:22457KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000339%
# size=   22457KiB time=00:11:58.62 bitrate= 256.0kbits/s speed=5.99e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58bdf1e35540] Guessed Channel Layout: stereo
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_data/down_1082.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:14:58.62, bitrate: 32 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, stereo, s16, 32 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/ENFify/notebooks/Talkbank_cut_data/cut_down_1082.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, stereo, s16, 32 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58bdf1e1d780] video:0KiB audio:2807KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002714%
# size=    2807KiB time=00:11:58.62 bitrate=  32.0kbits/s speed=7.81e+03x

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf'

max_cut = 120
max_coord = 360
cut_len = [np.random.randint(0, max_cut) for i in range(130)]
i_cut = [np.random.randint(150, 360) for i in range(130)]

files, cut_files = ffmpeg_filenames_cut(input_dir, output_dir)

for i in range(len(files)):
    cut_audio(files[i], cut_files[i], i_cut[i], (i_cut[i]+cut_len[i]))
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x651f939d8200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/092_ref.wav':
#   Duration: 00:04:28.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_092_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x651f939d83c0] video:0KiB audio:209KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.036380%
# size=     209KiB time=00:04:28.00 bitrate=   6.4kbits/s speed=1.14e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5c57ff0e9200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/036_ref.wav':
#   Duration: 00:10:03.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_036_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5c57ff0e93c0] video:0KiB audio:463KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.016470%
# size=     463KiB time=00:09:52.00 bitrate=   6.4kbits/s speed=1.45e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x558cd4d2a200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/087_ref.wav':
#   Duration: 00:09:58.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_087_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x558cd4d2a3c0] video:0KiB audio:377KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.020228%
# size=     377KiB time=00:08:02.00 bitrate=   6.4kbits/s speed=1.09e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55c5db2a1200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/078_ref.wav':
#   Duration: 00:10:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_078_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55c5db2a13c0] video:0KiB audio:427KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.017824%
# size=     427KiB time=00:09:07.00 bitrate=   6.4kbits/s speed=1.4e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a92db084200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/081_ref.wav':
#   Duration: 00:10:02.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_081_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a92db0843c0] video:0KiB audio:377KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.020186%
# size=     377KiB time=00:08:03.00 bitrate=   6.4kbits/s speed=9.61e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x650570716200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/075_ref.wav':
#   Duration: 00:09:55.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_075_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6505707163c0] video:0KiB audio:404KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.018859%
# size=     404KiB time=00:08:37.00 bitrate=   6.4kbits/s speed=1.23e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60c7195c0200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/018_ref.wav':
#   Duration: 00:11:46.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_018_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x60c7195c03c0] video:0KiB audio:532KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.014317%
# size=     532KiB time=00:11:21.00 bitrate=   6.4kbits/s speed=2.73e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5619772f2200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/029_ref.wav':
#   Duration: 00:11:24.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_029_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5619772f23c0] video:0KiB audio:523KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.014574%
# size=     523KiB time=00:11:09.00 bitrate=   6.4kbits/s speed=2.97e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e8d98ffa200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/114_ref.wav':
#   Duration: 00:09:33.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_114_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e8d98ffa3c0] video:0KiB audio:371KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.020526%
# size=     371KiB time=00:07:55.00 bitrate=   6.4kbits/s speed=2.26e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e34f1480200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/063_ref.wav':
#   Duration: 00:10:47.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_063_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e34f14803c0] video:0KiB audio:433KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.017599%
# size=     433KiB time=00:09:14.00 bitrate=   6.4kbits/s speed=2.43e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x59d65fbd0200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/094_ref.wav':
#   Duration: 00:10:09.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_094_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x59d65fbd03c0] video:0KiB audio:457KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.016667%
# size=     457KiB time=00:09:45.00 bitrate=   6.4kbits/s speed=2.42e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a74664c8200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/048_ref.wav':
#   Duration: 00:11:36.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_048_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a74664c83c0] video:0KiB audio:460KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.016553%
# size=     460KiB time=00:09:49.00 bitrate=   6.4kbits/s speed=2.19e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6051542d2200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/045_ref.wav':
#   Duration: 00:10:07.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_045_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6051542d23c0] video:0KiB audio:400KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.019043%
# size=     400KiB time=00:08:32.00 bitrate=   6.4kbits/s speed=2.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a64aaad5200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/010_ref.wav':
#   Duration: 00:12:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_010_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a64aaad53c0] video:0KiB audio:525KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.014509%
# size=     525KiB time=00:11:12.00 bitrate=   6.4kbits/s speed=2.25e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5fb169121200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/038_ref.wav':
#   Duration: 00:15:53.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_038_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5fb1691213c0] video:0KiB audio:723KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010529%
# size=     724KiB time=00:15:26.00 bitrate=   6.4kbits/s speed=2.62e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x56d11d576200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/055_ref.wav':
#   Duration: 00:10:24.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_055_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x56d11d5763c0] video:0KiB audio:445KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.017105%
# size=     445KiB time=00:09:30.00 bitrate=   6.4kbits/s speed=2.64e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e2c44969200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/020_ref.wav':
#   Duration: 00:11:45.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_020_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e2c449693c0] video:0KiB audio:473KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.016116%
# size=     473KiB time=00:10:05.00 bitrate=   6.4kbits/s speed=2.49e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b1c96851200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/123_ref.wav':
#   Duration: 00:08:36.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_123_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b1c968513c0] video:0KiB audio:333KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.022887%
# size=     333KiB time=00:07:06.00 bitrate=   6.4kbits/s speed=1.98e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5bdf3f4d4200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/065_ref.wav':
#   Duration: 00:10:22.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_065_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5bdf3f4d43c0] video:0KiB audio:431KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.017663%
# size=     431KiB time=00:09:12.00 bitrate=   6.4kbits/s speed=2.44e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5adc99e74200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/130_ref.wav':
#   Duration: 00:10:55.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_130_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5adc99e743c0] video:0KiB audio:460KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.016553%
# size=     460KiB time=00:09:49.00 bitrate=   6.4kbits/s speed=2.44e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5d10d5c80200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/003_ref.wav':
#   Duration: 00:10:52.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_003_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5d10d5c803c0] video:0KiB audio:504KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.015116%
# size=     504KiB time=00:10:45.00 bitrate=   6.4kbits/s speed=2.72e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x611165a30200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/001_ref.wav':
#   Duration: 00:08:02.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_001_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x611165a303c0] video:0KiB audio:338KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.022517%
# size=     338KiB time=00:07:13.00 bitrate=   6.4kbits/s speed=2.43e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e4e0d5a6200] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/reference_enf/093_ref.wav':
#   Duration: 00:09:59.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/one_cut_ref_enf/cut_093_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e4e0d5a63c0] video:0KiB audio:406KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.018750%
# size=     406KiB time=00:08:40.00 bitrate=   6.4kbits/s speed=2.3e+04x

# %%
def cut_out(input_file, output_file, start, end):
    os.system(f'. /home/$USER/miniforge3/etc/profile.d/conda.sh; conda activate enfify; ffmpeg -ss {start} -i {input_file} -t {end} -c copy {output_file}')

def minute_list_files_in_directory(input_dir, output_dir):
    try:
        # List all files in the directory
        files = os.listdir(input_dir)
        # Filter out directories, only keep files
        raw_files = [f for f in files if os.path.isfile(os.path.join(input_dir, f))]
        down_files = []
        files = []

        for raw in raw_files:
            down_file = output_dir + '/min_'+raw
            down_files.append(down_file)
        
        for raw in raw_files:
            files.append(input_dir + '/' + raw)

        return files, down_files

    except FileNotFoundError:
        return f"The directory {input_dir} does not exist."
    except PermissionError:
        return f"Permission denied to access {input_dir}."

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy'

files, min_files =   minute_list_files_in_directory(input_dir, output_dir)

for i in range(len(files)):
    cut_out(files[i], min_files[i], 10, 60)
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62ec81e25680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/036.wav':
#   Duration: 00:10:03.06, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_036.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x62ec81e25800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=7.88e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5d405cec3680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/116.wav':
#   Duration: 00:09:39.92, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_116.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5d405cec3800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.41 bitrate= 127.2kbits/s speed=1.08e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ece475f4680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/079.wav':
#   Duration: 00:09:57.95, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_079.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5ece475f4800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.22 bitrate= 127.6kbits/s speed=8.76e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x577e51e03680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/121.wav':
#   Duration: 00:09:39.92, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_121.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x577e51e03800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.54 bitrate= 126.9kbits/s speed=9.36e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e514a259680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/106.wav':
#   Duration: 00:09:53.62, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_106.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5e514a259800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=1.09e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5644fbdcd680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/117.wav':
#   Duration: 00:05:52.00, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_117.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5644fbdcd800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.09 bitrate= 127.9kbits/s speed=1.24e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60b6a4d85680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/101.wav':
#   Duration: 00:10:01.87, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_101.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x60b6a4d85800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.35 bitrate= 127.3kbits/s speed=9.17e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x633173b25680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/095.wav':
#   Duration: 00:09:59.48, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_095.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x633173b25800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.28 bitrate= 127.5kbits/s speed=1.21e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b67aab53680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/025.wav':
#   Duration: 00:14:21.88, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_025.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5b67aab53800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.48 bitrate= 127.1kbits/s speed=1.12e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x592292042680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/113.wav':
#   Duration: 00:09:59.43, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_113.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x592292042800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.22 bitrate= 127.6kbits/s speed=1.28e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5f50f52da680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/098.wav':
#   Duration: 00:10:59.58, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_098.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5f50f52da800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.22 bitrate= 127.6kbits/s speed=1.32e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ec34fb21680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/124.wav':
#   Duration: 00:09:52.53, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_124.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5ec34fb21800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.09 bitrate= 127.9kbits/s speed=1.23e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61bbb602f680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/053.wav':
#   Duration: 00:07:19.89, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_053.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x61bbb602f800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.41 bitrate= 127.2kbits/s speed=1.53e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5567f4ccf680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/097.wav':
#   Duration: 00:09:54.61, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_097.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5567f4ccf800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=1.55e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61f8c6d16680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/109.wav':
#   Duration: 00:10:05.88, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_109.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x61f8c6d16800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.35 bitrate= 127.3kbits/s speed=1.39e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e725fdb1680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/103.wav':
#   Duration: 00:10:10.11, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_103.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5e725fdb1800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=1.65e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x625f4bf2c680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/091.wav':
#   Duration: 00:09:56.06, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_091.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x625f4bf2c800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.22 bitrate= 127.6kbits/s speed=1.72e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5f56deac0680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/071.wav':
#   Duration: 00:10:01.22, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_071.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5f56deac0800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.22 bitrate= 127.6kbits/s speed=1.72e+04x
# ...
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5f3d4233a680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/120.wav':
#   Duration: 00:09:52.53, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_120.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x5f3d4233a800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.35 bitrate= 127.3kbits/s speed=1.38e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x56fcceac1680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/014.wav':
#   Duration: 00:11:52.18, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_014.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x56fcceac1800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=1.67e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6401e518d680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/083.wav':
#   Duration: 00:10:00.65, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_083.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x6401e518d800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.28 bitrate= 127.5kbits/s speed=1.7e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x649367352680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/028.wav':
#   Duration: 00:09:29.70, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_028.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x649367352800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.35 bitrate= 127.3kbits/s speed=1.59e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x612b682be680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/064.wav':
#   Duration: 00:10:22.52, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_064.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x612b682be800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.41 bitrate= 127.2kbits/s speed=1.33e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62514c652680] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/raw/ENF-WHU-Dataset/enf_real_world_recordings/013.wav':
#   Duration: 00:10:38.25, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_013.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0x62514c652800] video:0KiB audio:938KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008121%
# size=     938KiB time=00:01:00.16 bitrate= 127.7kbits/s speed=1.41e+04x

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref'

files, cut_files = ffmpeg_filenames_cut(input_dir, output_dir)
cut_len = [np.random.randint(1, 3) for i in range(130)]
i_cut = [np.random.randint(3, 8) for i in range(130)]

for i in range(len(files)):
    cut_audio(files[i], cut_files[i], i_cut[i], (i_cut[i]+cut_len[i]))
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x600a3ef8b3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_053_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_053_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x600a3ef8b580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.65e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5fb3b2a463c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_127_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_127_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5fb3b2a46580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.43e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x57b9c12c43c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_023_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_023_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x57b9c12c4580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.68e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61ed562503c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_089_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_089_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x61ed56250580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.13e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55958645f3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_091_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_091_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55958645f580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.81e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x635bc89873c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_080_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_080_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x635bc8987580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.79e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a6c8063e3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_090_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_090_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a6c8063e580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.59e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6212b2d133c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_111_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_111_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6212b2d13580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.78e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6074f8b0e3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_020_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_020_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6074f8b0e580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.58e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ef8d647c3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_124_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_124_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5ef8d647c580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.28e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62d78d2ac3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_028_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_028_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x62d78d2ac580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.52e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b3a1ede13c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_120_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_120_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b3a1ede1580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.88e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5d68ff7e13c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_096_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_096_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5d68ff7e1580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.38e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61cc7eb0c3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_098_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_098_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x61cc7eb0c580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.55e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x588a42ec93c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_002_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_002_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x588a42ec9580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=1.3e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ab62632e3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_087_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_087_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5ab62632e580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=1.64e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e0a1ecf23c0] Guessed Channel Layout: mono
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5fddd4e823c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_037_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_037_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5fddd4e82580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=4.03e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e7dbffdb3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_017_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_017_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e7dbffdb580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=4.05e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x591f766513c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_059_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_059_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x591f76651580] video:0KiB audio:7KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.083333%
# size=       7KiB time=00:00:09.00 bitrate=   6.5kbits/s speed=3.86e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58a8d41643c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_026_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_026_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58a8d4164580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=3.41e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62a055aea3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_081_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_081_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x62a055aea580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=3.62e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a78526da3c0] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/10s_enf_ref/min_027_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/10s_ref/cut_10s_enf_ref/cut_min_027_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a78526da580] video:0KiB audio:6KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.218750%
# size=       6KiB time=00:00:08.00 bitrate=   6.5kbits/s speed=2.86e+03x

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data'

files, cut_files = minute_list_files_in_directory(input_dir, output_dir)
cut_len = [np.random.randint(1, 19) for i in range(130)]
i_cut = [np.random.randint(20, 41) for i in range(130)]

for i in range(len(files)):
    cut_audio(files[i], cut_files[i], i_cut[i], (i_cut[i]+cut_len[i]))
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b520507f540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_053_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_053_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b520508fa40] video:0KiB audio:40KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.191176%
# size=      40KiB time=00:00:51.00 bitrate=   6.4kbits/s speed=5.3e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62f59c020540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_127_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_127_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x62f59c030a40] video:0KiB audio:44KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.174107%
# size=      44KiB time=00:00:56.00 bitrate=   6.4kbits/s speed=6.59e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x558240ff6540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_023_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_023_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x558241006a40] video:0KiB audio:36KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.211957%
# size=      36KiB time=00:00:46.00 bitrate=   6.4kbits/s speed=7.75e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x566fe6ad6540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_089_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_089_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x566fe6ae6a40] video:0KiB audio:39KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.195000%
# size=      39KiB time=00:00:50.00 bitrate=   6.4kbits/s speed=7.92e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a5ca6b7e540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_091_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_091_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a5ca6b8ea40] video:0KiB audio:41KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.187500%
# size=      41KiB time=00:00:52.00 bitrate=   6.4kbits/s speed=9.19e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60657db2c540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_080_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_080_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x60657db3ca40] video:0KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.168103%
# size=      45KiB time=00:00:58.00 bitrate=   6.4kbits/s speed=1.1e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61c65499e540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_090_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_090_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x61c6549aea40] video:0KiB audio:41KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.183962%
# size=      41KiB time=00:00:53.00 bitrate=   6.4kbits/s speed=1.03e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x571edae3c540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_111_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_111_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x571edae4ca40] video:0KiB audio:41KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.187500%
# size=      41KiB time=00:00:52.00 bitrate=   6.4kbits/s speed=9.8e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x59b7457ac540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_020_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_020_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x59b7457bca40] video:0KiB audio:35KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.216667%
# size=      35KiB time=00:00:45.00 bitrate=   6.4kbits/s speed=1.16e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x652968fd0540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_124_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_124_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x652968fe0a40] video:0KiB audio:33KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.232143%
# size=      33KiB time=00:00:42.00 bitrate=   6.4kbits/s speed=9.54e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6290fe7aa540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_028_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_028_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6290fe7baa40] video:0KiB audio:44KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.174107%
# size=      44KiB time=00:00:56.00 bitrate=   6.4kbits/s speed=1.23e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x59a1fc197540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_120_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_120_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x59a1fc1a7a40] video:0KiB audio:41KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.183962%
# size=      41KiB time=00:00:53.00 bitrate=   6.4kbits/s speed=1.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x578e93c88540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_096_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_096_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x578e93c98a40] video:0KiB audio:36KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.211957%
# size=      36KiB time=00:00:46.00 bitrate=   6.4kbits/s speed=1.15e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55f3b501d540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_098_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_098_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55f3b502da40] video:0KiB audio:34KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.226744%
# size=      34KiB time=00:00:43.00 bitrate=   6.4kbits/s speed=1.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61c6cb7e3540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_002_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_002_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x61c6cb7f3a40] video:0KiB audio:38KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.198980%
# size=      38KiB time=00:00:49.00 bitrate=   6.4kbits/s speed=1e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55fe400eb540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_087_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_087_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55fe400fba40] video:0KiB audio:38KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.198980%
# size=      38KiB time=00:00:49.00 bitrate=   6.4kbits/s speed=1.12e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x576d3a9e4540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_037_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_037_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x576d3a9f4a40] video:0KiB audio:40KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.191176%
# size=      40KiB time=00:00:51.00 bitrate=   6.4kbits/s speed=1.21e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x587589a2a540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_017_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_017_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x587589a3aa40] video:0KiB audio:38KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.198980%
# size=      38KiB time=00:00:49.00 bitrate=   6.4kbits/s speed=1.31e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5e223af27540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_059_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_059_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5e223af37a40] video:0KiB audio:34KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.221591%
# size=      34KiB time=00:00:44.00 bitrate=   6.4kbits/s speed=1.03e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b0d9735d540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_026_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_026_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b0d9736da40] video:0KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.177273%
# size=      43KiB time=00:00:55.00 bitrate=   6.4kbits/s speed=1.41e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60a2ec4a0540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_081_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_081_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x60a2ec4b0a40] video:0KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.171053%
# size=      45KiB time=00:00:57.00 bitrate=   6.4kbits/s speed=1.65e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a2d498ac540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/1min_enf_ref_data/min_027_ref.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.00, bitrate: 6 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_ref/cut_1min_enf_ref_data/min_min_027_ref.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 400 Hz, mono, s16, 6 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a2d498bca40] video:0KiB audio:34KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.226744%
# size=      34KiB time=00:00:43.00 bitrate=   6.4kbits/s speed=1.17e+04x

# %%
for i in range(len(cut_len)):
    print(f'cut coord {i_cut[i]} | cut len {cut_len[i]}')

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut'

files, cut_files = ffmpeg_filenames_cut(input_dir, output_dir)
cut_len = [np.random.randint(1, 19) for i in range(130)]
i_cut = [np.random.randint(20, 41) for i in range(130)]

for i in range(len(files)):
    cut_audio(files[i], cut_files[i], i_cut[i], (i_cut[i]+cut_len[i]))
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a7a92bc2540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_084.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_084.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a7a92bc2700] video:0KiB audio:797KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009553%
# size=     797KiB time=00:00:51.03 bitrate= 128.0kbits/s speed=5.52e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x617f00d6e540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_106.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_106.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x617f00d6e700] video:0KiB audio:750KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010149%
# size=     751KiB time=00:00:48.03 bitrate= 128.0kbits/s speed=5.44e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58a59704a540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_042.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_042.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58a59704a700] video:0KiB audio:766KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009942%
# size=     766KiB time=00:00:49.03 bitrate= 128.0kbits/s speed=6.27e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x6074dc5fc540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_037.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_037.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x6074dc5fc700] video:0KiB audio:876KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008700%
# size=     876KiB time=00:00:56.03 bitrate= 128.0kbits/s speed=7.91e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x598671da6540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_012.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_012.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x598671da6700] video:0KiB audio:672KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.011329%
# size=     672KiB time=00:00:43.03 bitrate= 128.0kbits/s speed=7.55e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ac5bf021540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_053.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_053.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5ac5bf021700] video:0KiB audio:735KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010365%
# size=     735KiB time=00:00:47.03 bitrate= 128.0kbits/s speed=6.13e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x561193822540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_104.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_104.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x561193822700] video:0KiB audio:797KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009553%
# size=     797KiB time=00:00:51.03 bitrate= 128.0kbits/s speed=9.38e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b5682229540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_027.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_027.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b5682229700] video:0KiB audio:844KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009022%
# size=     844KiB time=00:00:54.03 bitrate= 128.0kbits/s speed=9.62e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b245065e540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_060.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_060.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b245065e700] video:0KiB audio:735KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010365%
# size=     735KiB time=00:00:47.03 bitrate= 128.0kbits/s speed=7.5e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a8bf16f9540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_023.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_023.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a8bf16f9700] video:0KiB audio:657KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.011598%
# size=     657KiB time=00:00:42.03 bitrate= 128.0kbits/s speed=7.11e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58e3fbd88540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_033.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_033.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58e3fbd88700] video:0KiB audio:719KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010590%
# size=     719KiB time=00:00:46.03 bitrate= 128.0kbits/s speed=9e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x599521bd4540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_063.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_063.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x599521bd4700] video:0KiB audio:750KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010149%
# size=     751KiB time=00:00:48.03 bitrate= 128.0kbits/s speed=8.97e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5b8997227540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_113.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_113.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5b8997227700] video:0KiB audio:688KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.011071%
# size=     688KiB time=00:00:44.03 bitrate= 128.0kbits/s speed=8.56e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x628e56508540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_040.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_040.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x628e56508700] video:0KiB audio:797KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009553%
# size=     797KiB time=00:00:51.03 bitrate= 128.0kbits/s speed=1.03e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x60561aeb2540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_074.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_074.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x60561aeb2700] video:0KiB audio:719KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.010590%
# size=     719KiB time=00:00:46.03 bitrate= 128.0kbits/s speed=8.73e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x624e36d43540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_116.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_116.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x624e36d43700] video:0KiB audio:922KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008258%
# size=     922KiB time=00:00:59.03 bitrate= 128.0kbits/s speed=1.03e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x603c9d3da540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_044.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_044.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x603c9d3da700] video:0KiB audio:813KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009369%
# size=     813KiB time=00:00:52.03 bitrate= 128.0kbits/s speed=1.11e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58f9551d4540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_123.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_123.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58f9551d4700] video:0KiB audio:688KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.011071%
# size=     688KiB time=00:00:44.03 bitrate= 128.0kbits/s speed=8.49e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5841a456d540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_117.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_117.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5841a456d700] video:0KiB audio:829KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009193%
# size=     829KiB time=00:00:53.03 bitrate= 128.0kbits/s speed=1.02e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x579d56669540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_039.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_039.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x579d56669700] video:0KiB audio:657KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.011598%
# size=     657KiB time=00:00:42.03 bitrate= 128.0kbits/s speed=8.79e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x57a33550b540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_032.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_032.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x57a33550b700] video:0KiB audio:829KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009193%
# size=     829KiB time=00:00:53.03 bitrate= 128.0kbits/s speed=1.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55d53114f540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy/min_076.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:01:00.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   Stream #0:0 (pcm_s16le) -> atrim:default
#   concat:out:a0 -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_076.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55d53114f700] video:0KiB audio:782KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009744%
# size=     782KiB time=00:00:50.03 bitrate= 128.0kbits/s speed=9.17e+03x

# %%
input_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut'
output_dir = '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut'


rawFile_name, downFile_name = list_files_in_directory(input_dir, output_dir)


for i in range(len(rawFile_name)):
    downsampling(rawFile_name[i], downFile_name[i], fs_down = 1000)
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5fa8249e4540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_071.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:42.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_071.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5fa8249e46c0] video:0KiB audio:82KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.092786%
# size=      82KiB time=00:00:42.03 bitrate=  16.0kbits/s speed=5.5e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x601ea3341540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_108.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:49.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_108.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x601ea33416c0] video:0KiB audio:96KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.079540%
# size=      96KiB time=00:00:49.03 bitrate=  16.0kbits/s speed=6.63e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x59949d241540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_101.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:43.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_101.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x59949d2416c0] video:0KiB audio:84KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.090630%
# size=      84KiB time=00:00:43.03 bitrate=  16.0kbits/s speed=6.07e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x55c794629540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_047.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:57.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_047.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x55c7946296c0] video:0KiB audio:111KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.068383%
# size=     111KiB time=00:00:57.03 bitrate=  16.0kbits/s speed=7.91e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x63f02c31d540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_039.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:42.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_039.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x63f02c31d6c0] video:0KiB audio:82KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.092786%
# size=      82KiB time=00:00:42.03 bitrate=  16.0kbits/s speed=8.95e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x600cb7706540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_121.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:52.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_121.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x600cb77066c0] video:0KiB audio:102KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.074954%
# size=     102KiB time=00:00:52.03 bitrate=  16.0kbits/s speed=1.05e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x596a7612d540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_063.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:48.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_063.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x596a7612d6c0] video:0KiB audio:94KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.081196%
# size=      94KiB time=00:00:48.03 bitrate=  16.0kbits/s speed=9.38e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5c7219a9b540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_081.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:49.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_081.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5c7219a9b6c0] video:0KiB audio:96KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.079540%
# size=      96KiB time=00:00:49.03 bitrate=  16.0kbits/s speed=1e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5c4deadcf540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_091.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:53.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_091.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5c4deadcf6c0] video:0KiB audio:104KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.073541%
# size=     104KiB time=00:00:53.03 bitrate=  16.0kbits/s speed=1.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x62093ab8b540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_073.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:52.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_073.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x62093ab8b6c0] video:0KiB audio:102KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.074954%
# size=     102KiB time=00:00:52.03 bitrate=  16.0kbits/s speed=1.1e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5639abdb3540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_097.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:46.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_097.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5639abdb36c0] video:0KiB audio:90KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.084724%
# size=      90KiB time=00:00:46.03 bitrate=  16.0kbits/s speed=1.04e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x63d9a3dfe540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_083.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:49.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_083.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x63d9a3dfe6c0] video:0KiB audio:96KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.079540%
# size=      96KiB time=00:00:49.03 bitrate=  16.0kbits/s speed=1.09e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5ebc92729540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_046.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:46.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_046.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5ebc927296c0] video:0KiB audio:90KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.084724%
# size=      90KiB time=00:00:46.03 bitrate=  16.0kbits/s speed=8.85e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5adc4be4f540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_068.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:47.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_068.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5adc4be4f6c0] video:0KiB audio:92KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.082922%
# size=      92KiB time=00:00:47.03 bitrate=  16.0kbits/s speed=1.09e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5d76f2a77540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_031.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:51.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_031.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5d76f2a776c0] video:0KiB audio:100KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.076423%
# size=     100KiB time=00:00:51.03 bitrate=  16.0kbits/s speed=9.56e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x65173e804540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_004.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:53.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_004.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x65173e8046c0] video:0KiB audio:104KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.073541%
# size=     104KiB time=00:00:53.03 bitrate=  16.0kbits/s speed=1.16e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a8edc5de540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_005.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:47.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_005.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5c99a86cc540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_030.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:54.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_030.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5c99a86cc6c0] video:0KiB audio:106KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.072179%
# size=     106KiB time=00:00:54.03 bitrate=  16.0kbits/s speed=1.16e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x58e132ff3540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_128.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:44.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_128.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x58e132ff36c0] video:0KiB audio:86KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.088572%
# size=      86KiB time=00:00:44.03 bitrate=  16.0kbits/s speed=1.09e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x564a60bee540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_089.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:58.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_089.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x564a60bee6c0] video:0KiB audio:113KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.067204%
# size=     113KiB time=00:00:58.03 bitrate=  16.0kbits/s speed=1.21e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x566dc63c1540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_041.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:44.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_041.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x566dc63c16c0] video:0KiB audio:86KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.088572%
# size=      86KiB time=00:00:44.03 bitrate=  16.0kbits/s speed=1.05e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x5a4bfe6e9540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_018.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:51.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_018.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x5a4bfe6e96c0] video:0KiB audio:100KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.076423%
# size=     100KiB time=00:00:51.03 bitrate=  16.0kbits/s speed=9.86e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-13)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1719926049773/_build_env/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [aist#0:0/pcm_s16le @ 0x61b75aae5540] Guessed Channel Layout: mono
# Input #0, wav, from '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_cut/cut_min_050.wav':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:00:52.03, bitrate: 128 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 8000 Hz, mono, s16, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/home/leo_dacasi/Dokumente/summerofcode/Enfify_Data_Synced/interim/ENF-WHU-Dataset/1min_noise/1min_noisy_down_cut/down_cut_min_050.wav':
#   Metadata:
#     ISFT            : Lavf61.1.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 1000 Hz, mono, s16, 16 kb/s
#       Metadata:
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x61b75aae56c0] video:0KiB audio:102KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.074954%
# size=     102KiB time=00:00:52.03 bitrate=  16.0kbits/s speed=1.09e+04x
